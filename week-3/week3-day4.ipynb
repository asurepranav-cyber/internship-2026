# %%
""" 
create a sample text file with some text in it
""";

# %%
# open the file

f = open("sample.txt")

# %%
print(f)
# Out:
# <_io.TextIOWrapper name='sample.txt' mode='r' encoding='cp1252'>

# %%
f.readable()
# Out:
# True

# %%
f.readline()
# Out:
# 'This is a sample text file.\n'

# %%
f.readline()
# Out:
# 'Hello from Python!\n'

# %%
f.readline()
# Out:
# 'Have a great day.\n'

# %%
f.readline()
# Out:
# ''

# %%
f = open("sample.txt")

# %%
f.readline(10)
# Out:
# 'This is a '

# %%
f.readline(5)
# Out:
# 'sampl'

# %%
f.tell()
# Out:
# 15

# %%
f.seek(10)
# Out:
# 10

# %%
f.readline(5)
# Out:
# 'sampl'

# %%
# check readlines

# %%
f = open("sample.txt")

# %%
data = f.readlines()

# %%
data
# Out:
# ['This is a sample text file.\n',
#  'Hello from Python!\n',
#  'Have a great day.\n']

# %%
for line in data:
    print(line)
# Out:
# This is a sample text file.
#
# Hello from Python!
#
# Have a great day.

# %%
# convert the data in upper case

# %%
for line in data:
    print(line.upper())
# Out:
# THIS IS A SAMPLE TEXT FILE.
#
# HELLO FROM PYTHON!
#
# HAVE A GREAT DAY.

# %%
# read function

# %%
f = open("sample.txt")

# %%
text = f.read()

# %%
text
# Out:
# 'This is a sample text file.\nHello from Python!\nHave a great day.\n'

# %%
print(text)
# Out:
# This is a sample text file.
# Hello from Python!
# Have a great day.

# %%
text.split();

# %%
m = open('maha.txt', encoding= 'utf-8')

# %%
print(m.read())
# Out:
# साहित्यामध्ये गद्य-पद्य घटकांचा आस्वाद घेताना आपण अनेक रस अनुभवतो. गद्य-पद्य घटकांतून
# चपखलपणे व्यक्त होणारा आशय, दोन ओळींमधील गर्भितार्थ, रूपकात्मक भाषा, पद्य घटकांतील अलंकार,
# सूचकता, प्रसाद, माधुर्य हे काव्यगुण पदोपदी प्रत्ययास येतात. अर्थपूर्ण रचनांचा रसास्वाद घेण्याची कला आत्मसात
# झाली, की त्यामुळे मिळणारा आनंद अवर्णनीय असतो. भाषासमृद्धीसाठी ‘रसास्वाद’ या घटकाकडे आवर्जून लक्ष
# देऊया.

# %%
m.close()

# %%
m.readable()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 m.readable()
#
# ValueError: I/O operation on closed file

# %%
# opening a file with context manager

# %%
with open('sample.txt') as f:
    data = f.read()

# %%
print(data)
# Out:
# This is a sample text file.
# Hello from Python!
# Have a great day.

# %%
# writing in a file

# %%
f = open('myfile.txt', 'w')

# %%
f.readable()
# Out:
# False

# %%
f.writable()
# Out:
# True

# %%
lines = ['frodo took the ring.', 'he started his journey to mount doom.' ]

# %%
f.writelines(lines)

# %%
f.close()

# %%
# writelines -> takes the list of sentences from user and writes them in the file

# %%
# write()

# %%
sent = "frodo took the ring. he started his journey to mount doom."

# %%
f = open('myfile.txt', 'w')
f.write(sent)
f.close()

# %%
# write into a myfile.txt with context manager
# use write function and add 3 separate lines

# %%
with open('myfile.txt', 'w') as f:
    f.write('this is first line\n')
    f.write('this is second\n')
    f.write('this is third\n')

# %%
# simple file copy operation

# %%
s = open('sample.txt', 'r')
f = open('myfile.txt', 'w')

# %%
contents = s.read()
f.write(contents)
f.close()

# %%
# append

# %%
s = open('sample.txt', 'a')

# %%
s.write('\ndone')
# Out:
# 5

# %%
s.close()
